# %%
#文件操作

"""
 文件上传：保存头像
 文件保存：
 系统函数：open(file,mode)

"""
# Out:
# '\n 文件上传：保存头像\n 文件保存：\n 系统函数：open(file,mode)\n\n'

# %%
"""
mode : r   w
       rb  wb
       
 rb: read binary
 wb: write binary
 
 读写纯文本文件时

"""

# %%
"""

文件上传：客户上传

文件下载：客户下载


"""

# %%
"""
read:

"""
# Out:
# '\nread:\n\n'

# %%
#help(open)

# %%
f = open(r'C:\Users\yaoyuping\Desktop\Python code\test.txt')
f.read()
# Out:
# '[(-1.5387900529867595+0j), (-1.5387900529867595-4.5792848186864955e-17j), (-1.5387900529867595-4.5792848186864937e-17j), (-1.5387900529867597+0j), (-1.5387900529867593-9.15856963737299e-17j), (-1.5387900529867584+9.158569637372991e-17j), (-1.5387900529867597+0j), (-1.5387900529867595+3.601437878801969e-18j), (-1.53879005298676+8.798425849492793e-17j), (-1.5387900529867595+0j), (-2.4460305432836886-1.0132034232582982e-16j), (-2.446030543283688+2.0264068465165963e-16j), (-2.4460305432836886-1.0132034232582979e-16j), (-2.446030543283688-2.3114809217910493e-17j), (-2.446030543283687+4.8878458192449575e-18j), (-2.4460305432836895+4.8878458192449575e-18j), (-2.446030543283688+2.3114809217910493e-17j), (-2.446030543283688-2.3114809217910474e-17j), (-2.446030543283686+0j), (-2.4460305432836886+1.0132034232582982e-16j), (-1.4578239357463068+2.019620609441185e-17j), (-1.4578239357463068-1.3398165355847666e-16j), (-1.4578239357463065+9.358924136965294e-17j), (-1.4578239357463074-4.679462068482
# ...
